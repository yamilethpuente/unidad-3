# %% [markdown]
# <a href="https://colab.research.google.com/github/yamilethpuente/unidad-3/blob/main/actividad3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# conceptos basicos de la libreria matplotlib es una libreria de trazados de basicos de dado nivel en python que sirve como una herramienta de visualizacion matoplotlib es de codigo abierto y podemos utilizarlo libremente matplotlib esta escrito principalmente en python con algunos segmentos escritos c.
# instalacion de matplotlib
# si tienes python y pip ya instalado en tu sistema, instala matplotlib usando el siguiente comando

# %%
# !pip install matplotlib

# %% [markdown]
# desde la linea de comando
# importar matplotlib una vez instalado matplotlib importalo en tus aplicaciones agregando el modulo import, ejemplo

# %%
import matplotlib

# %% [markdown]
# matplotlib pyplot
# pyplot se encuentra dentro del submodulo pyplot y normalmente se importa bajo el alias PLT

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ahora el paquete pyplot predenominara plt
